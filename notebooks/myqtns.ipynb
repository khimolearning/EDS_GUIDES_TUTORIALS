# %% [markdown]
# dns server contains ip addresses, so when u type a website to the internet, the server looks for its IP adress. if it fails u get a not found error.
# qtn: does it mean when i create a website i have to submit to a dns server to get an ip address? or how does it work?

# %% [markdown]
# to reach a destination on the web, ur pc needs the following;
# needs a number ---> it asks the DNS Server what is the phone no. of this website?
# needs a connection
# needs a language
# what happens split second as u press enter
