# %% [markdown]
# # Python Imports

# %% [markdown]
# ## 1. import xxx:
#
# import the entire module or library. it then becomes accessible through prefix. as seen below.
#
# ### example
#
# ```
# import math
# result = math.sqrt(16)
# print(result)  # Output: 4.0
# ```

# %% [markdown]
# ### 2. from xxx import yyy
#
# This imports only a specific function, class, or variable from a module, allowing you to use it directly by name without needing a prefix.
#
# ### example
#
# ```
# from math import sqrt
# result = sqrt(16)
# print(result)
# ```

# %% [markdown]
# ### 3. import xxx as zz
#
# Sometimes, you might want to use a shorter name for a module. You can use as to rename the module when importing.
#
# ### example:
#
# ```
# import math as mt
# result = mt.sqrt(16)
# print(result)
# ```

# %%
import math  # Imports the entire math module
from random import randint  # Only imports randint from random
from random import randint as ri
import math as mts

# Using math.pi
print("Pi:", math.pi)  # Output: 3.141592653589793
print("Pi:", mts.pi)

# Using randint directly
print("Random integer:", randint(1, 10))  # Output: A random number between 1 and 10
print("Random integer:", ri(1, 10))

# %% [markdown]
# # Python with functions:

# %%
def greet():
    print("Hello, world!")

greet()

# %% [markdown]
# # Adding Arguments to a Function
#
# Arguments are values you pass into the function to make it work with specific data. For example, if you want the `greet` function to greet a specific person, you could add an argument called `name`.

# %%
def greet(name):
    print("Hello, " + name + "!")

greet("Alice")
greet("Tope")

# %% [markdown]
# ## leap year calculation
#
# Think of it as two ways to win the "Leap Year" title:
#
# - The Standard Way: Divisible by 4 but NOT by 100. (e.g., 2024, 2028)
# - The Special Exception: Divisible by 400. (e.g., 2000, 2400)

# %%
def is_leap_year(year):
  if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("this is a leap year")
  else:
    print("so not a leap year")

is_leap_year(2026)

# %%
def add_numbers(a, b):
  result = a + b
  print(result)

add_numbers(5, 6)

# %% [markdown]
# # Return Values
#
# 1. Sometimes, instead of just printing the result, we want the function to return a value so we can use it elsewhere. To do this, we use the return keyword. Here’s an example that returns the sum of two numbers:
#
# ```
# def add_numbers(a, b):
#     result = a + b
#     return result
# ```
#
# 2. Now, when we call add_numbers(5, 10), we can store the result in a variable or use it in other expressions:
#
# ```
# sum_result = add_numbers(5, 10)
# print(sum_result)
# ```
#
# 3. This is helpful because we can now use sum_result in other calculations:
#
# ```
# double_sum = sum_result * 2
# print(double_sum)
# ```

# %%
def add_numbers(a, b):
    result = a + b
    return result

sum_result = add_numbers(5, 10)
print(sum_result)


double_sum = sum_result * 2
print(double_sum)

# %% [markdown]
# # Default Arguments
#
# You can also set default values for arguments. If an argument with a default value is not provided, Python will use the default. This can make functions more flexible.
#
# ```
# def greet(name="stranger"):
#     print("Hello, " + name + "!")
# ```
#
# If you call greet() without an argument, it will use "stranger" as the name:
#
# ```
# greet()
#
# Output:
# Hello, stranger!
# ```
#
# You can still provide a name, which will override the default:
#
# ```
# greet("Alice")
#
# Output:
# Hello, Alice!
# ```

# %%
def greet(name = "stranger"):
  print(f"hello {name}!")

greet()

def length(l = 4):
  print(f"since default measurement for l is {l}, input b")

length()

# %% [markdown]
# # A Function with Multiple Arguments and Return Value
#
# Let’s create a function that calculates the area of a rectangle. It takes two arguments: width and height, and returns the area.
#
# ```
# def calculate_area(width, height):
#     area = width * height
#     return area
# ```

# %%
def calculate_area(width, height):
    area = width * height
    return area

area_1 = calculate_area(5, 3)
area_2 = calculate_area(4, 6)
perimeter = area_1 + area_2

print(f"area_1, area_2 and perimeter is {area_1}, {area_2} and {perimeter} respectively")

# %% [markdown]
# # Python Strings
#
# Let's go over some common aspects of Python strings and methods in an approachable way, breaking things down into core concepts and examples:
#
# ## 1. Basic String Manipulation in Python
#
# Python strings are sequences of characters and offer many useful methods and tools.
#
# Common String Methods:
#
# len() - Returns the length of the string.
# The length counts every character, including spaces and punctuation.
#
# ```
# text = "Hello, world!"
# print(len(text))  # Output: 13
# ```
#
# replace() - Replaces a part of the string with another substring.
#
# ```
# greeting = "Hello, world!"
# new_greeting = greeting.replace("world", "Python")
# print(new_greeting)  # Output: "Hello, Python!"
# ```
#
# strip() - Removes any whitespace (spaces, newlines) from the beginning and end of the string.
#
# ```
# messy_text = "   Hello, world!   "
# clean_text = messy_text.strip()
# print(clean_text)  # Output: "Hello, world!"
# ```
#
# split() - Divides a string into a list of substrings based on a specified separator (default is whitespace).
#
# ```
# sentence = "Hello world Python is great"
# words = sentence.split()
# print(words)  # Output: ['Hello', 'world', 'Python', 'is', 'great']
# ```
#
# join() - Combines a list of strings into a single string, with each element separated by the string it was called on.
#
# ```
# words = ['Hello', 'world', 'Python', 'is', 'great']
# sentence = " ".join(words)
# print(sentence)  # Output: "Hello world Python is great"
# ```
#
# Slicing - Extracts parts of a string by specifying a range of indices.
#
# ```
# text = "Hello, world!"
# print(text[0:5])   # Output: "Hello"
# print(text[-6:])   # Output: "world!"
# text[start:end] extracts the substring starting at index start and ending at end-1.
# Negative indices start from the end, so text[-6:] extracts from the sixth-to-last character to the end.
# ```
#
# ## 2. Multi-line Strings
#
# In Python, there are two ways to create multi-line strings:
#
# Backslash \ - Use it at the end of each line to continue the string onto the next line without adding a line break.
#
# ```
# multi_line_string = "This is a string that is too long to fit on one line, so we continue it \
# here without any breaks."
# print(multi_line_string)
# ```
#
# This prints as a single line, with no breaks, because the backslash \ tells Python to ignore the line break.
#
# Triple Quotes ''' or """ - Use triple quotes for a string that spans multiple lines and includes line breaks.
#
# ```
# multi_line_quote = """This is a string
# that contains multiple lines,
# and we don't need to use a backslash.
# It also handles quotes, like "this one" and 'that one'."""
# print(multi_line_quote)
# ```
#
# 3. Triple-Quoted Strings as Docstrings
#
# Triple-quoted strings are commonly used in Python as docstrings, which are comments that describe what a function, class, or module does. They are placed immediately after the function or class definition.
#
# ```
# def greet(name):
#     """
#     This function takes a name as input and returns a greeting string.
#     Parameters:
#     name (str): The name of the person to greet.
#     Returns:
#     str: A greeting message.
#     """
#     return f"Hello, {name}!"
# ```
#
# Purpose: Docstrings serve as documentation for your code, helping others understand what the function does, what inputs it takes, and what output it produces.

# %%
fruits = "      mango apple orange pineapple papaya banana berry grape passion_fruit almond_fruit"
fruits_clean = fruits.strip() #remove white spaces
print(fruits_clean)
list_fruits = fruits.split()  #make everything a list of items
print(list_fruits)

# %% [markdown]
# # f-string formatting

# %%
import datetime
date = datetime.datetime.now()
formatted_date = f"today's date is: {date: %d %B, %Y}"
print(formatted_date)

# %%
price = 540000.309900
print(f"the cost of living is ${price:.2f} ") # "." formats to 2 decimal places

# %%
price = 540000.309900
print(f"the cost of living is ${price:,.2f} ") # "," adds a comma seperator for "thousand"

# %% [markdown]
# the course instructor assumed the reader knows what "working with files in python" is. it did not define it, did not explain the use, the scenerio it is needed, the idea behind it. also in his explanation, he assumed the reader is familiar with every new concept introduced eg in introducing some terms out of the blues like what is pathlib, glob and the rest of these jargons? because it what it looks like to a beginner. just pure jargon. now start all over with the explanation and assume the reader is truly a beginner and has no knowledge in this topic and of course is coming across the terms and concepts associated with this topic.

# %% [markdown]
# ## PATH AND GLOB REAL USE CASES;
#
# A Step-by-Step Practical Demonstration
# To move from abstract to "I can see it," let's pretend we are building a Photo Organizer.
#
# The Mission: You have a folder called My_Vacation, and inside it is a subfolder called Beach_Photos. You want to find every .jpg image in that subfolder.
#
# ### Step 1: Point to the Folders (The Map)
#
# We use Path to define the "Address."
#
# ```
# from pathlib import Path
# Building the 'GPS' address
# 'My_Vacation' is the main folder, 'Beach_Photos' is the subfolder
#
# photo_location = Path("My_Vacation") / "Beach_Photos"
# ```
#
# ### Step 2: Search for the Files (The Filter)
#
# Now we use glob to look inside that specific address for only .jpg files.
#
# ```
# import glob
# # We combine the Address with the Search Pattern (*.jpg)
# # str() turns the 'Map' into 'Text' so the search engine can read it
#
# search_query = str(photo_location / "*.jpg")
# # This gives us a LIST of every photo found
# all_photos = glob.glob(search_query)
# ```
#
# Step 3: The Result
# If you had three photos, your all_photos list would now look like this:
# ['My_Vacation/Beach_Photos/sunset.jpg', 'My_Vacation/Beach_Photos/ocean.jpg', 'My_Vacation/Beach_Photos/sand.jpg']

# %%
from pathlib import Path

# Building the 'GPS' address
# 'My_Vacation' is the main folder, 'Beach_Photos' is the subfolder
photo_location = Path("My_Vacation") / "Beach_Photos"

import glob

# We combine the Address with the Search Pattern (*.jpg)
# str() turns the 'Map' into 'Text' so the search engine can read it
search_query = str(photo_location / "*.jpg")

# This gives us a LIST of every photo found
all_photos = glob.glob(search_query)

# %%
from pathlib import Path
import glob

# 1. SETUP: Create the address to the subfolder
# Pathlib handles the 'Company_Data\Daily_Reports' (Windows) vs 'Company_Data/Daily_Reports' (Mac) logic for you

report_path = Path("Company_Data") / "Daily_Reports"

# 2. SEARCH: Find every .txt file inside that subfolder
# The * is the wildcard: 'Find anything as long as it ends in .txt'
search_engine = str(report_path / "*.txt")
found_files = glob.glob(search_engine)

# 3. ACTION: Print the names of the files we found
print(f"I found {len(found_files)} files in the subfolder!")
for file in found_files:
    print(f"Located: {file}")

# %% [markdown]
# # The "Safety Check" Syntax
#
# In the real world, a program will crash if you tell it to look in a folder that doesn't exist (maybe someone deleted it or you misspelled it). Using pathlib gives you a "Superpower" to check the folder before you even start the search.
#
# We use the .exists() method. It is a simple True/False check.

# %%
from pathlib import Path

# 1. Define the 'Map' to the subfolder
report_path = Path("Company_Data") / "Daily_Reports"

# 2. The Safety Check
if report_path.exists():
    print("Folder found! Proceeding to search...")
    # This is where you would put your glob.glob() code
else:
    print("Error: The folder 'Daily_Reports' does not exist in 'Company_Data'.")

# %% [markdown]
# # full picture from start to finish
#
# this is the full picture, combining every single detail from start to finish
# import pathlib, glob
# step 1; variable = Path("name of folder")/ "name of subfolder"
# step 2; check if it exists `if variable.exists():`
# indent everything under it
# search variable = str(variable / "\*.txt")
# found variable = glob.glob(search variable)

# %%
from pathlib import Path
import glob

# STEP 1: Define the GPS Map (Pathlib)
# 'Company_Data' is the Parent, 'Daily_Reports' is the Subfolder
report_path = Path("Company_Data") / "Daily_Reports"

# STEP 2: Safety Check (Does the folder actually exist?)
if report_path.exists():
    
    # STEP 3: Search Engine (Glob)
    # Find all .txt files starting with 'March_'
    search_query = str(report_path / "March_*.txt")
    found_files = glob.glob(search_query)
    
    # STEP 4: Action (The 'With' Airlock)
    if found_files:
        print(f"Success! Found {len(found_files)} reports.")
        
        for file_name in found_files:
            with open(file_name, "r", encoding="utf-8") as f:
                # Just read the first line as a preview
                preview = f.readline()
                print(f"File: {file_name} | Preview: {preview.strip()}")
    else:
        print("Folder exists, but no March reports were found inside.")

else:
    print("Mission Aborted: The folder path is incorrect.")
