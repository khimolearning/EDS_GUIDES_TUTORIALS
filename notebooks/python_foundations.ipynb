# %%
import math as m
square_root = m.sqrt(25)
print(square_root)

# %% [markdown]
# FUNCTIONS:
# You can also set default values for arguments. If an argument with a default value is not provided, Python will use the default. This can make functions more flexible.

# %%
def greet(name="Crush!"):
    print("Hello, " + name + "!")

greet()

# %%
greet()

# %%
def even_numbers(): # No need for x here since range(50) defines it
  for x in range(50):
    if x % 2 == 0:
      print(x, "is an even number") # Use print so the loop keeps going
    else:
      print(x, "is not an even number")

even_numbers()

# %%
def calculate_area(w, h):
  area = w * h
  return area

area_1 = calculate_area(2,5)
print("Area of the rectangle: =" , area_1)

# %%
def leap_year(year):
  if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    return True
  else:
    return False
  

is_this_year_leap = leap_year(2026)
print(is_this_year_leap)
